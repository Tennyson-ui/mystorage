# %% [markdown]
# # 00 - Verificar ambiente
#
# Verificacao basica do ambiente Python/JupyterLab para a Atividade 3 SWOT. Este notebook nao baixa dados e nao autentica automaticamente no Earthdata.

# %%
import importlib
import os
import platform
from pathlib import Path

print('OK Python:', platform.python_version())
print('OK diretorio atual:', Path.cwd())
print('OK HOME:', os.environ.get('HOME', '(nao definido)'))
# Out:
# OK Python: 3.11.4
# OK diretorio atual: /home/jovyan
# OK HOME: /home/jovyan

# %%
packages = [
    'earthaccess',
    'xarray',
    'netCDF4',
    'h5netcdf',
    'pandas',
    'geopandas',
    'shapely',
    'pyproj',
    'matplotlib',
    'ipyleaflet',
    'ipywidgets',
    'fiona',
    'pyogrio',
    'numpy',
    'requests',
    'pyarrow',
]

for package in packages:
    try:
        module = importlib.import_module(package)
        version = getattr(module, '__version__', 'versao nao informada')
        print(f'OK {package}: {version}')
    except Exception as exc:
        print(f'FALHA {package}: {exc}')
# Out:
# OK earthaccess: 0.17.0
# OK xarray: 2026.7.0
# OK netCDF4: 1.7.4
# OK h5netcdf: 1.8.1
# OK pandas: 3.0.5
# OK geopandas: 1.1.4
# OK shapely: 2.1.2
# OK pyproj: 3.7.2
# OK matplotlib: 3.11.1
# OK ipyleaflet: 0.20.0
# OK ipywidgets: 8.1.7
# OK fiona: 1.10.1
# OK pyogrio: 0.13.0
# OK numpy: 2.4.6
# OK requests: 2.31.0
# OK pyarrow: 25.0.1

# %%
output_dir = Path('../../outputs/logs').resolve()
output_dir.mkdir(parents=True, exist_ok=True)
test_file = output_dir / 'check_notebook.tmp'

try:
    test_file.write_text('ok\n', encoding='utf-8')
    test_file.unlink(missing_ok=True)
    print('OK escrita em:', output_dir)
except Exception as exc:
    print('FALHA escrita:', exc)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/conda/lib/python3.11/pathlib.py:1116, in Path.mkdir(self, mode, parents, exist_ok)
#    1115 try:
# -> 1116     os.mkdir(self, mode)
#    1117 except FileNotFoundError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/outputs/logs'
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[3], line 2
#       1 output_dir = Path('../../outputs/logs').resolve()
# ----> 2 output_dir.mkdir(parents=True, exist_ok=True)
#       3 test_file = output_dir / 'check_notebook.tmp'
#       5 try:
#
# File /opt/conda/lib/python3.11/pathlib.py:1120, in Path.mkdir(self, mode, parents, exist_ok)
#    1118     if not parents or self.parent == self:
#    1119         raise
# -> 1120     self.parent.mkdir(parents=True, exist_ok=True)
#    1121     self.mkdir(mode, parents=False, exist_ok=exist_ok)
#    1122 except OSError:
#    1123     # Cannot rely on checking for EEXIST, since the operating system
#    1124     # could give priority to other errors like EACCES or EROFS
#
# File /opt/conda/lib/python3.11/pathlib.py:1116, in Path.mkdir(self, mode, parents, exist_ok)
#    1112 """
#    1113 Create a new directory at this given path.
#    1114 """
#    1115 try:
# -> 1116     os.mkdir(self, mode)
#    1117 except FileNotFoundError:
#    1118     if not parents or self.parent == self:
#
# PermissionError: [Errno 13] Permission denied: '/outputs'

# %%
try:
    import ipywidgets as widgets
    from ipyleaflet import Map
    display(widgets.HTML('<b>OK ipywidgets</b>'))
    display(Map(center=(0, 0), zoom=2))
    print('OK ipyleaflet')
except Exception as exc:
    print('FALHA widgets/mapa:', exc)
# Out:
# HTML(value='<b>OK ipywidgets</b>')
# Map(center=[0, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text'…
# OK ipyleaflet

# %% [markdown]
# ## Observacao
#
# A autenticacao Earthdata deve ser feita manualmente nos notebooks de download quando a atividade for executada. Nenhuma chamada de login ou download e realizada aqui.
